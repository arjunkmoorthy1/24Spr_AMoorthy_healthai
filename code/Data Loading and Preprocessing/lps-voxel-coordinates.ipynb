# %%
import pydicom
import matplotlib.pyplot as plt
import os

# %%
#read a dicom slice
img = pydicom.dcmread('/Users/arjunmoorthy/Desktop/targeted_bx_dicoms/targeted_bx_slices/Prostate-MRI-US-Biopsy-0001/1-20.dcm')

# %%
img.InstanceNumber,img.SliceLocation,img.SliceThickness,img.PixelSpacing
# Out:
# ('20', '-46.381074011326', '1.5', [0.6640625, 0.6640625])

# %%
x, y, z = (10.005, 14.1, 78.225) #Las cords

# %%
(x-(img.ImagePositionPatient[0]))/img.PixelSpacing[0]
# Out:
# 177.59945553706163

# %%
(y-(img.ImagePositionPatient[1]))/img.PixelSpacing[1]
# Out:
# 120.6881686587151

# %%
arr = img.pixel_array #extract the dicom slice

# %%
plt.figure(figsize=(10,10))
plt.imshow(arr,cmap='gray')
plt.scatter(158,122,c ="blue")
