# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
import pydicom
from PIL import Image

# %%
import os
import pydicom

def load_dicom_images_with_labels(root_dir):
    patient_data = {}
    tract_labels = {}

    # Iterate over 'cancer' and 'non_cancer' directories
    for label_dir in ['cancer', 'non_cancer']:
        label_path = os.path.join(root_dir, label_dir)

        # Check if the label_path is indeed a directory (ignore if not)
        if not os.path.isdir(label_path):
            continue

        label = 1 if label_dir == 'cancer' else 0

        # Iterate over patients within each label directory
        for patient in os.listdir(label_path):
            patient_path = os.path.join(label_path, patient)

            # Check if the patient_path is indeed a directory
            if not os.path.isdir(patient_path):
                continue

            tracts = patient_data.get(patient, {})

            # Iterate over tracts for each patient
            for tract in os.listdir(patient_path):
                tract_path = os.path.join(patient_path, tract)

                # Check if the tract_path is indeed a directory
                if not os.path.isdir(tract_path):
                    continue

                images = []

                # Load DICOM images
                for filename in os.listdir(tract_path):
                    if filename.endswith('.dcm'):
                        file_path = os.path.join(tract_path, filename)
                        if os.path.isfile(file_path):  # Ensure the path is a file
                            ds = pydicom.dcmread(file_path)
                            images.append(ds.pixel_array)
                            print(f"Loaded DICOM image from {file_path}")  # Debug: Print loaded file path

                if not images:
                    print(f"No DICOM images loaded for tract at {tract_path}")  # Debug: Notify if no images loaded

                # Save images and labels
                tracts[tract] = images
                tract_key = f"{label_dir}/{patient}/{tract}"
                tract_labels[tract_key] = label

            # Update the patient data with new or modified tracts
            patient_data[patient] = tracts

    return patient_data, tract_labels

# %%
import cv2
import numpy as np

def preprocess_image(image):
    # Normalize the input image to 8-bit if not already
    if image.dtype != np.uint8:
        norm_image = cv2.normalize(image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    else:
        norm_image = image

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    clahe_img = clahe.apply(norm_image)

    # Re-normalize to 0-1 range if necessary for your application
    final_image = clahe_img.astype(np.float32) / 255

    return final_image

# %%
from skimage.feature import graycomatrix, graycoprops

def extract_features(image):
    # Ensure image is scaled back to uint8 for GLCM
    image_uint8 = (image * 255).astype(np.uint8)

    # Compute GLCM and extract features
    glcm = graycomatrix(image_uint8, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4], 256, symmetric=True, normed=True)
    contrast = graycoprops(glcm, 'contrast').flatten()
    energy = graycoprops(glcm, 'energy').flatten()

    # Histogram features
    hist = cv2.calcHist([image_uint8], [0], None, [256], [0, 256]).flatten()

    return np.concatenate([contrast, energy, hist])

# %%
def aggregate_features(tracts):
    tract_features = []
    for tract, images in tracts.items():
        if images:  # Check if there are images
            all_features = [extract_features(preprocess_image(image)) for image in images]
            aggregated = np.mean(all_features, axis=0)  # Calculate mean of features
        else:
            print(f"No images to process for tract: {tract}")
            aggregated = np.nan  # Use NaN or a suitable default to indicate no data

        tract_features.append(aggregated)
    return tract_features

# %%
from sklearn.decomposition import PCA

def reduce_dimensions(features):
    pca = PCA(n_components=10)  # reduce to 10 dimensions
    reduced_features = pca.fit_transform(features)
    return reduced_features, pca

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

def train_classifier(features, labels):
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)
    clf = RandomForestClassifier(random_state=42)
    clf.fit(X_train, y_train)
    return clf, X_test, y_test

# %%
from sklearn.metrics import roc_auc_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report


def evaluate_classifier_extended(clf, X_test, y_test):
    # Predict probabilities for AUC
    y_probs = clf.predict_proba(X_test)[:, 1]  # probabilities for the positive class
    # Predict class labels for other metrics
    y_pred = clf.predict(X_test)

    # Calculate metrics
    auc = roc_auc_score(y_test, y_probs)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    
    # Print metrics
    print(f'Accuracy: {clf.score(X_test, y_test)}')
    print(f'AUC: {auc}')
    print(f'Recall: {recall}')
    print(f'Precision: {precision}')
    print(f'F1 Score: {f1}')
    print("Confusion Matrix:")
    print(confusion)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

# %%
# Load data and labels
root_directory = '/Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data'
all_data, all_labels = load_dicom_images_with_labels(root_directory)

# Prepare features and labels for ML
features_list = []
labels_list = []

for patient, tracts in all_data.items():
    for tract, images in tracts.items():
        # Check if there are no images in the current tract
        if not images:
            print(f"Skipping empty tract for patient {patient}: {tract}")
            continue  # Skip this tract entirely as there are no images to process

        # Determine the correct label directory for each tract
        label_dir = next((key.split('/')[0] for key in all_labels.keys() if key.endswith(f"{patient}/{tract}")), None)
        
        # Check if the label directory was found
        if label_dir is None:
            print(f"No label directory found for {patient}/{tract}")
            continue

        # Form the correct key with label_dir
        key = f"{label_dir}/{patient}/{tract}"

        # Extract and aggregate features for each tract
        tract_features = aggregate_features({tract: images})
        features_list.extend(tract_features)

        # Append the label for each tract
        labels_list.append(all_labels[key])  # Using the correctly prefixed key

# Convert lists to numpy arrays
features_array = np.array(features_list)
labels_array = np.array(labels_list)

# Apply PCA if necessary
if features_array.shape[1] > 10:  # Check if PCA is necessary
    features_array, pca = reduce_dimensions(features_array)

# Train and evaluate the classifier
clf, X_test, y_test = train_classifier(features_array, labels_array)
evaluate_classifier_extended(clf, X_test, y_test)
# Out:
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-33.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9129_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9127_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9131_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9131_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9131_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1135/biopsy_9131_cancer/1-25.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0013/biopsy_128_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3701_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3703_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3697_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3697_cancer/1-33.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3707_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3705_cancer/1-21.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3705_cancer/1-20.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3705_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3705_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3699_cancer/1-40.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3699_cancer/1-35.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3699_cancer/1-36.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3699_cancer/1-37.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3699_cancer/1-39.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3699_cancer/1-38.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3700_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3698_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0448/biopsy_3704_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0828/biopsy_7376_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0828/biopsy_7379_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0828/biopsy_7375_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0828/biopsy_7373_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-35.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-36.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-33.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1919_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1915_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1915_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1915_cancer/1-28.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1918_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1914_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0226/biopsy_1916_cancer/1-37.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5569_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5589_cancer/1-42.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5589_cancer/1-43.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5589_cancer/1-44.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5589_cancer/1-45.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5589_cancer/1-46.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5587_cancer/1-50.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5587_cancer/1-51.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5587_cancer/1-47.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5587_cancer/1-48.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0642/biopsy_5587_cancer/1-49.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-42.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-43.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-41.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-40.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-44.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-45.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-47.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-46.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-39.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-48.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3847_cancer/1-49.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3849_cancer/1-37.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3849_cancer/1-38.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0470/biopsy_3850_cancer/1-36.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-14.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-15.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-17.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-16.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-12.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-13.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3977_cancer/1-11.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-09.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-08.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-20.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-33.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-18.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-19.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3988_cancer/1-10.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3986_cancer/1-21.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3986_cancer/1-06.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3986_cancer/1-07.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3986_cancer/1-05.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3986_cancer/1-04.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-42.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-43.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-41.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-40.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-44.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-45.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3967_cancer/1-39.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3973_cancer/1-35.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3973_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3973_cancer/1-36.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3973_cancer/1-37.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3973_cancer/1-38.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3985_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3989_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3978_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3966_cancer/1-50.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3966_cancer/1-51.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3966_cancer/1-47.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3966_cancer/1-46.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3966_cancer/1-48.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3966_cancer/1-49.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0484/biopsy_3983_cancer/1-03.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9113_cancer/1-29.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9111_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9115_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9112_cancer/1-32.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9110_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-1132/biopsy_9114_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-35.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-33.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7242_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7240_cancer/1-36.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7239_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7244_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7244_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7244_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7244_cancer/1-25.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7246_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7243_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7245_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0817/biopsy_7238_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-21.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6071_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6075_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6072_cancer/1-20.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6072_cancer/1-18.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6072_cancer/1-19.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0689/biopsy_6074_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-038.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-039.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-032.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-033.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-031.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-034.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-035.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-037.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0674/biopsy_5872_cancer/1-036.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-50.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-45.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-51.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-47.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-46.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-33.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-48.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3662_cancer/1-49.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3660_cancer/1-53.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3660_cancer/1-52.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3660_cancer/1-35.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3660_cancer/1-36.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3664_cancer
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3661_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3677_cancer/1-14.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3677_cancer/1-15.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3677_cancer/1-12.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3677_cancer/1-13.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3677_cancer/1-11.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3667_cancer/1-43.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3667_cancer/1-44.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3667_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3667_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3679_cancer/1-09.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3679_cancer/1-08.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3679_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3679_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3679_cancer/1-07.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0446/biopsy_3679_cancer/1-10.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_233_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_233_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_233_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_233_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_233_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_233_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_231_cancer/1-21.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0022/biopsy_232_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-50.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-45.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-51.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-47.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-52.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-46.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-48.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1712_cancer/1-49.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-09.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-08.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-34.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-33.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-32.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-03.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-02.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-12.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-06.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-07.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-13.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-05.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-11.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-10.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1702_cancer/1-04.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1714_cancer/1-53.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1696_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1704_cancer/1-35.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1704_cancer/1-14.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1708_cancer/1-54.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1713_cancer/1-43.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1713_cancer/1-44.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1713_cancer/1-22.dcm
# No DICOM images loaded for tract at /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1711_cancer
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0210/biopsy_1707_cancer/1-55.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-09.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-08.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-27.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-26.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-30.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-31.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-25.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-28.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-29.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-12.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-07.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-13.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-11.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7287_cancer/1-10.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-42.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-43.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-41.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-40.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-44.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-45.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-46.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-22.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-23.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7272_cancer/1-24.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-21.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-20.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-19.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-01.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-03.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-02.dcm
# Loaded DICOM image from /Users/arjunmoorthy/Desktop/Research_Capstone/ImageData/new_train_data/cancer/Prostate-MRI-US-Biopsy-0821/biopsy_7291_cancer/1-06.dcm
# ...
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7213_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7216_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7221_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7218_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7209_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7222_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7215_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7206_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7217_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7220_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0812: biopsy_7212_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1130: biopsy_9096_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1130: biopsy_9093_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1130: biopsy_9098_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1130: biopsy_9092_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0029: biopsy_297_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0732: biopsy_6427_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0500: biopsy_4093_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0500: biopsy_4095_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0190: biopsy_1533_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0190: biopsy_1532_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1045: biopsy_8769_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0155: biopsy_1271_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0155: biopsy_1268_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0360: biopsy_3027_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0536: biopsy_4528_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6528_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6531_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6536_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6533_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6522_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6540_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6530_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6521_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6538_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6524_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6535_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6529_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6532_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6523_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6526_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0750: biopsy_6537_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1020: biopsy_8660_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1020: biopsy_8662_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1020: biopsy_8661_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1020: biopsy_8663_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1020: biopsy_8659_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0905: biopsy_7920_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0902: biopsy_7899_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1011: biopsy_8614_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1011: biopsy_8612_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1011: biopsy_8610_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0305: biopsy_2538_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_954_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_948_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_945_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_946_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_943_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_952_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_949_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_944_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0108: biopsy_950_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0934: biopsy_8126_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0934: biopsy_8127_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0130: biopsy_1091_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0130: biopsy_1087_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0395: biopsy_3262_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0395: biopsy_3261_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0361: biopsy_3030_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0153: biopsy_1255_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0359: biopsy_3023_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0368: biopsy_3063_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0368: biopsy_3065_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0555: biopsy_4701_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0555: biopsy_4699_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0555: biopsy_4702_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0555: biopsy_4700_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0555: biopsy_4705_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5195_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5198_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5204_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5201_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5202_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5199_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5207_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5196_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5200_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5208_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0599: biopsy_5205_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0335: biopsy_2766_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0335: biopsy_2764_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1003: biopsy_8557_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1003: biopsy_8560_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6792_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6797_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6800_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6799_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6791_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6796_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0773: biopsy_6793_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0780: biopsy_6865_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0319: biopsy_2633_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0319: biopsy_2634_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0319: biopsy_2631_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0789: biopsy_6952_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0742: biopsy_6492_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0742: biopsy_6490_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0742: biopsy_6489_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0928: biopsy_8081_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0928: biopsy_8082_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0928: biopsy_8085_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0745: biopsy_6502_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0745: biopsy_6500_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0524: biopsy_4380_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1092: biopsy_8967_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0386: biopsy_3194_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0386: biopsy_3192_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0343: biopsy_2852_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0582: biopsy_4976_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0582: biopsy_4973_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0582: biopsy_4975_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8079_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8073_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8070_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8069_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8075_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8078_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8080_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8072_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8077_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0927: biopsy_8066_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0772: biopsy_6789_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0772: biopsy_6786_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0772: biopsy_6785_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0772: biopsy_6788_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0772: biopsy_6787_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0772: biopsy_6782_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0345: biopsy_2860_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0662: biopsy_5733_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0662: biopsy_5731_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0468: biopsy_3817_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0698: biopsy_6128_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0698: biopsy_6131_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0005: biopsy_21_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0005: biopsy_24_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0495: biopsy_4060_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0495: biopsy_4058_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0801: biopsy_7144_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0492: biopsy_4046_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0290: biopsy_2422_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0290: biopsy_2427_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0290: biopsy_2424_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0290: biopsy_2430_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0290: biopsy_2423_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0069: biopsy_708_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0069: biopsy_703_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0069: biopsy_706_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0069: biopsy_704_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0607: biopsy_5260_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0607: biopsy_5262_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0607: biopsy_5258_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0852: biopsy_7566_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0852: biopsy_7564_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0255: biopsy_2160_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0255: biopsy_2166_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0255: biopsy_2161_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0255: biopsy_2164_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0890: biopsy_7837_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0890: biopsy_7840_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0299: biopsy_2498_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0299: biopsy_2495_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0655: biopsy_5643_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0655: biopsy_5645_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0460: biopsy_3794_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0460: biopsy_3792_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0460: biopsy_3795_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0652: biopsy_5620_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1140: biopsy_9153_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1140: biopsy_9150_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1140: biopsy_9149_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0630: biopsy_5452_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0630: biopsy_5449_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0050: biopsy_544_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0262: biopsy_2232_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0262: biopsy_2226_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1149: biopsy_9193_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-1149: biopsy_9192_non_cancer
# Skipping empty tract for patient Prostate-MRI-US-Biopsy-0853: biopsy_7570_non_cancer
# Accuracy: 0.5761658031088083

# %%
import os
import pydicom

def load_dicom_images_with_labels(root_dir):
    patient_data = {}
    tract_labels = {}

    # Iterate over 'cancer' and 'non_cancer' directories
    for label_dir in ['cancer', 'non_cancer']:
        label_path = os.path.join(root_dir, label_dir)
        label = 1 if label_dir == 'cancer' else 0

        # Iterate over patients within each label directory
        for patient in os.listdir(label_path):
            patient_path = os.path.join(label_path, patient)
            tracts = {}

            # Iterate over tracts for each patient
            for tract in os.listdir(patient_path):
                tract_path = os.path.join(patient_path, tract)
                images = []

                # Load DICOM images
                for filename in os.listdir(tract_path):
                    if filename.endswith('.dcm'):
                        file_path = os.path.join(tract_path, filename)
                        ds = pydicom.dcmread(file_path)
                        images.append(ds.pixel_array)

                # Save images and labels
                tracts[tract] = images
                tract_labels[os.path.join(label_dir, patient, tract)] = label

            # If patient already exists in data (cross-label scenario), update it
            if patient in patient_data:
                patient_data[patient].update(tracts)
            else:
                patient_data[patient] = tracts

    return patient_data, tract_labels


import cv2
import numpy as np

def preprocess_image(image):
    # Normalize the input image to 8-bit if not already
    if image.dtype != np.uint8:
        norm_image = cv2.normalize(image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    else:
        norm_image = image

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    clahe_img = clahe.apply(norm_image)

    # Re-normalize to 0-1 range if necessary for your application
    final_image = clahe_img.astype(np.float32) / 255

    return final_image

from skimage.feature import greycomatrix, greycoprops

def extract_features(image):
    # Compute GLCM and extract contrast
    glcm = greycomatrix(image, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4], 256, symmetric=True, normed=True)
    contrast = greycoprops(glcm, 'contrast').flatten()
    energy = greycoprops(glcm, 'energy').flatten()

    # Histogram features
    hist = cv2.calcHist([image], [0], None, [256], [0, 256]).flatten()

    return np.concatenate([contrast, energy, hist])
def aggregate_features(tracts):
    tract_features = []
    for tract, images in tracts.items():
        all_features = [extract_features(preprocess_image(image)) for image in images]
        aggregated = np.mean(all_features, axis=0)  # Example of using mean
        tract_features.append(aggregated)
    return tract_features
from sklearn.decomposition import PCA

def reduce_dimensions(features):
    pca = PCA(n_components=10)  # reduce to 10 dimensions
    reduced_features = pca.fit_transform(features)
    return reduced_features, pca
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

def train_classifier(features, labels):
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)
    clf = RandomForestClassifier(random_state=42)
    clf.fit(X_train, y_train)
    return clf, X_test, y_test
def evaluate_classifier(clf, X_test, y_test):
    accuracy = clf.score(X_test, y_test)
    print(f'Accuracy: {accuracy}')
# Load data and labels
root_directory = 'path_to_data_directory'
all_data, all_labels = load_dicom_images_with_labels(root_directory)

# Prepare features and labels for ML
features_list = []
labels_list = []

for patient, tracts in all_data.items():
    for tract, images in tracts.items():
        # Extract and aggregate features for each tract
        tract_features = aggregate_features({tract: images})
        features_list.extend(tract_features)
        # Append the label for each tract
        labels_list.append(all_labels[patient + '/' + tract])

# Convert lists to numpy arrays
features_array = np.array(features_list)
labels_array = np.array(labels_list)

# Apply PCA if necessary
if features_array.shape[1] > 10:  # Check if PCA is necessary
    features_array = reduce_dimensions(features_array)

# Train and evaluate the classifier
clf, X_test, y_test = train_classifier(features_array, labels_array)
evaluate_classifier(clf, X_test, y_test)
